# %%
print("Chào các bạn !")
# Out:
# Chào các bạn !

# %%
print("Võ Hoàng Quân")
# Out:
# Võ Hoàng Quân

# %%
print("Mình về mình có nhớ ta?")
print("Mười lăm năm ấy thiết tha mặn nồng")
print("Mình về mình có nhớ không?")
print("Nhìn cây nhớ núi, nhìn sông nhớ nguồn")
# Out:
# Mình về mình có nhớ ta?
# Mười lăm năm ấy thiết tha mặn nồng
# Mình về mình có nhớ không?
# Nhìn cây nhớ núi, nhìn sông nhớ nguồn

# %%
thamso = input("Nhập tham số: ")
print(thamso)
# Out:
# Nhập tham số: Võ Hoàng Quân
# Võ Hoàng Quân

# %%
for i in range(4):
   if(i==0 or i==3):
       print("*" * 4)
   else:
       print("*" + " " * 2 + "*")
# Out:
# ****
# *  *
# *  *
# ****

# %%
for i in range(4):
   for j in range(9):
      print("*", end=" ")
   print("\n")
# Out:
# * * * * * * * * *
#
# * * * * * * * * *
#
# * * * * * * * * *
#
# * * * * * * * * *

# %%
print("      *      ")
print("     ***     ")
print("    *****    ")
print("     ***     ")
print("    *****    ")
print(" *********** ")
print("     * *     ")
print("     * *     ")
# Out:
#       *
#      ***
#     *****
#      ***
#     *****
#  ***********
#      * *
#      * *

# %%
arr = [1, 3, 7, 3, 5, 11]
for i in range(len(arr)):
   print(("*" * arr[i]).center(11))
for i in range(2):
   print(("* *").center(11))
# Out:
#      *
#     ***
#   *******
#     ***
#    *****
# ***********
#     * *
#     * *
